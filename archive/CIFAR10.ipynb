# %% [markdown]
# # Cifar 10 and K Nearest Neighbour testing
#
# This is a visual view of the data we obtain from calculating the K Nearest Neighbour for the Cifar 10 challenge.

# %%
import numpy as np
import matplotlib.pylab as pl
import matplotlib.pyplot as plt
import _pickle as pickle
import os
import scipy
from knn import NearestNeighbour
# %matplotlib inline

# %%
def load_CIFAR_batch(file):
    """ load single batch of cifar"""
    with open(file, 'rb') as f:
        datadict = pickle.load(f, encoding = 'latin1')
        X = datadict['data']
        Y = datadict['labels']
        X = X.reshape(10000,3,32,32).transpose(0,2,3,1).astype("float")
        Y = np.array(Y)
    return X, Y

def load_CIFAR10(ROOT):
    """ load all of cifar """
    xs = []
    ys = []
    for i in range(1,2):
        f = os.path.join(ROOT, 'data_batch_%d' % (i, ))
        X, Y = load_CIFAR_batch(f)
        xs.append(X)
        ys.append(Y)
    Xtr = np.concatenate(xs)
    Ytr = np.concatenate(ys)
    del X,Y
    """
    Xtr, Ytr = training data
    Xte, Yte = testing data
    """
    Xte, Yte = load_CIFAR_batch(os.path.join(ROOT, 'test_batch'))
    return Xtr, Ytr, Xte, Yte

# %%
def visualize_sample(X_train, y_train, classes, samples_per_class=10):
    """visualize some samples in the training datasets """
    num_classes = len(classes)
    for y, cls in enumerate(classes):
        idxs = np.flatnonzero(y_train == y) # get all the indexes of cls
        idxs = np.random.choice(idxs, samples_per_class, replace=False)
        for i, idx in enumerate(idxs): # plot the image one by one
            plt_idx = i * num_classes + y + 1 # i*num_classes and y+1 determine the row and column respectively
            plt.subplot(samples_per_class, num_classes, plt_idx)
            plt.imshow(X_train[idx].astype('uint8'))
            plt.axis('off')
            if i == 0:
                plt.title(cls)
    plt.show()

# %% [markdown]
# # Example of what we expect in our sample

# %%
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
Xtr, Ytr, Xte, Yte = load_CIFAR10('cifar-10-batches-py')
visualize_sample(Xtr, Ytr, classes)

# %%
def run_knn(Xtr,Ytr,Xte,Yte):
    
    # flattens out all images to be one dimensional
    Xtr_rows = Xtr.reshape(Xtr.shape[0], 32 * 32 * 3) # Xtr_rows become 50000x 3072
    Xte_rows = Xte.reshape(Xte.shape[0], 32 * 32 * 3) # Xtr_rows become 10000x 3072

    # assume we have Xtr_rows, Ytr, Xte_rows, Yte as before
    # recall Xtr_rows is 50,000 x 3072 matrix
    # Xval_rows = Xtr_rows[:1000, :] # take first 1000 for validation
    # Yval = Ytr[:1000]
    # Xtr_rows = Xtr_rows[1000:,:] # keep last 49,000 for train
    # Ytr = Ytr[1000:]

    validation_accuracies = []
    for k in [1]:
        nn = NearestNeighbour() # create a Nearest Neighbor classifier class
        nn.train(Xtr_rows, Ytr) # train the classifier on the training images and labels
        Yte_predict = nn.predict(Xte_rows, k) # predict labels on the test images
        # and now print the classification accuracy, which is the average number
        # of examples that are correctly predicted (i.e label matches)
        acc = np.mean(Yte_predict == Yte)
        print ( 'K-NN %d' % (k))
        print ( 'accuracy: %f' % (acc))
        
        validation_accuracies.append((k, acc))
    return Yte_predict

# %% [markdown]
# # Predicting the Cifar 10 output
# This is the part where we classify the test cases.
# Please note that task below takes about 2-3hrs to run and complete the task dependent on CPU
# Also note that jupyter notebook with continuous output will eventually put it into a box with scroll bar.

# %%
Yte_Predict = run_knn(Xtr,Ytr,Xte,Yte)
visualize_sample(Xte, Yte_Predict, classes)
# Out:
# Test case 0: 	 Predicted label is:frog
# Test case 1: 	 Predicted label is:ship
# Test case 2: 	 Predicted label is:ship
# Test case 3: 	 Predicted label is:ship
# Test case 4: 	 Predicted label is:deer
# Test case 5: 	 Predicted label is:deer
# Test case 6: 	 Predicted label is:cat
# Test case 7: 	 Predicted label is:bird
# Test case 8: 	 Predicted label is:cat
# Test case 9: 	 Predicted label is:ship
# Test case 10: 	 Predicted label is:plane
# Test case 11: 	 Predicted label is:ship
# Test case 12: 	 Predicted label is:dog
# Test case 13: 	 Predicted label is:frog
# Test case 14: 	 Predicted label is:plane
# Test case 15: 	 Predicted label is:bird
# Test case 16: 	 Predicted label is:dog
# Test case 17: 	 Predicted label is:cat
# Test case 18: 	 Predicted label is:car
# Test case 19: 	 Predicted label is:horse
# Test case 20: 	 Predicted label is:bird
# Test case 21: 	 Predicted label is:plane
# Test case 22: 	 Predicted label is:plane
# Test case 23: 	 Predicted label is:deer
# Test case 24: 	 Predicted label is:bird
# Test case 25: 	 Predicted label is:plane
# Test case 26: 	 Predicted label is:bird
# Test case 27: 	 Predicted label is:horse
# Test case 28: 	 Predicted label is:bird
# Test case 29: 	 Predicted label is:frog
# Test case 30: 	 Predicted label is:frog
# Test case 31: 	 Predicted label is:deer
# Test case 32: 	 Predicted label is:cat
# Test case 33: 	 Predicted label is:bird
# Test case 34: 	 Predicted label is:ship
# Test case 35: 	 Predicted label is:car
# Test case 36: 	 Predicted label is:frog
# Test case 37: 	 Predicted label is:plane
# Test case 38: 	 Predicted label is:deer
# Test case 39: 	 Predicted label is:dog
# Test case 40: 	 Predicted label is:plane
# Test case 41: 	 Predicted label is:frog
# Test case 42: 	 Predicted label is:cat
# Test case 43: 	 Predicted label is:deer
# Test case 44: 	 Predicted label is:plane
# Test case 45: 	 Predicted label is:ship
# Test case 46: 	 Predicted label is:dog
# Test case 47: 	 Predicted label is:ship
# Test case 48: 	 Predicted label is:deer
# Test case 49: 	 Predicted label is:deer
# Test case 50: 	 Predicted label is:ship
# Test case 51: 	 Predicted label is:ship
# Test case 52: 	 Predicted label is:ship
# Test case 53: 	 Predicted label is:cat
# Test case 54: 	 Predicted label is:ship
# Test case 55: 	 Predicted label is:ship
# Test case 56: 	 Predicted label is:cat
# Test case 57: 	 Predicted label is:car
# Test case 58: 	 Predicted label is:plane
# Test case 59: 	 Predicted label is:deer
# Test case 60: 	 Predicted label is:frog
# Test case 61: 	 Predicted label is:frog
# Test case 62: 	 Predicted label is:deer
# Test case 63: 	 Predicted label is:ship
# Test case 64: 	 Predicted label is:cat
# Test case 65: 	 Predicted label is:bird
# Test case 66: 	 Predicted label is:ship
# Test case 67: 	 Predicted label is:bird
# Test case 68: 	 Predicted label is:horse
# Test case 69: 	 Predicted label is:truck
# Test case 70: 	 Predicted label is:plane
# Test case 71: 	 Predicted label is:deer
# Test case 72: 	 Predicted label is:plane
# Test case 73: 	 Predicted label is:ship
# Test case 74: 	 Predicted label is:deer
# Test case 75: 	 Predicted label is:deer
# Test case 76: 	 Predicted label is:frog
# Test case 77: 	 Predicted label is:dog
# Test case 78: 	 Predicted label is:bird
# Test case 79: 	 Predicted label is:ship
# Test case 80: 	 Predicted label is:bird
# Test case 81: 	 Predicted label is:car
# Test case 82: 	 Predicted label is:deer
# Test case 83: 	 Predicted label is:cat
# Test case 84: 	 Predicted label is:horse
# Test case 85: 	 Predicted label is:bird
# Test case 86: 	 Predicted label is:dog
# Test case 87: 	 Predicted label is:plane
# Test case 88: 	 Predicted label is:ship
# Test case 89: 	 Predicted label is:car
# Test case 90: 	 Predicted label is:plane
# Test case 91: 	 Predicted label is:deer
# Test case 92: 	 Predicted label is:dog
# Test case 93: 	 Predicted label is:frog
# Test case 94: 	 Predicted label is:cat
# Test case 95: 	 Predicted label is:bird
# Test case 96: 	 Predicted label is:bird
# Test case 97: 	 Predicted label is:frog
# Test case 98: 	 Predicted label is:plane
# Test case 99: 	 Predicted label is:deer
# Test case 100: 	 Predicted label is:plane
# Test case 101: 	 Predicted label is:horse
# Test case 102: 	 Predicted label is:cat
# Test case 103: 	 Predicted label is:deer
# Test case 104: 	 Predicted label is:car
# Test case 105: 	 Predicted label is:plane
# Test case 106: 	 Predicted label is:cat
# Test case 107: 	 Predicted label is:frog
# Test case 108: 	 Predicted label is:dog
# Test case 109: 	 Predicted label is:dog
# Test case 110: 	 Predicted label is:bird
# Test case 111: 	 Predicted label is:plane
# Test case 112: 	 Predicted label is:cat
# Test case 113: 	 Predicted label is:ship
# Test case 114: 	 Predicted label is:ship
# Test case 115: 	 Predicted label is:frog
# Test case 116: 	 Predicted label is:deer
# Test case 117: 	 Predicted label is:truck
# Test case 118: 	 Predicted label is:ship
# Test case 119: 	 Predicted label is:deer
# Test case 120: 	 Predicted label is:ship
# Test case 121: 	 Predicted label is:deer
# Test case 122: 	 Predicted label is:bird
# Test case 123: 	 Predicted label is:bird
# Test case 124: 	 Predicted label is:ship
# Test case 125: 	 Predicted label is:deer
# Test case 126: 	 Predicted label is:plane
# Test case 127: 	 Predicted label is:bird
# Test case 128: 	 Predicted label is:frog
# Test case 129: 	 Predicted label is:bird
# Test case 130: 	 Predicted label is:deer
# Test case 131: 	 Predicted label is:car
# Test case 132: 	 Predicted label is:ship
# Test case 133: 	 Predicted label is:cat
# Test case 134: 	 Predicted label is:truck
# Test case 135: 	 Predicted label is:dog
# Test case 136: 	 Predicted label is:truck
# Test case 137: 	 Predicted label is:bird
# Test case 138: 	 Predicted label is:bird
# Test case 139: 	 Predicted label is:ship
# Test case 140: 	 Predicted label is:deer
# Test case 141: 	 Predicted label is:ship
# Test case 142: 	 Predicted label is:frog
# Test case 143: 	 Predicted label is:cat
# Test case 144: 	 Predicted label is:dog
# Test case 145: 	 Predicted label is:dog
# Test case 146: 	 Predicted label is:bird
# Test case 147: 	 Predicted label is:horse
# Test case 148: 	 Predicted label is:dog
# Test case 149: 	 Predicted label is:cat
# Test case 150: 	 Predicted label is:ship
# Test case 151: 	 Predicted label is:cat
# Test case 152: 	 Predicted label is:cat
# Test case 153: 	 Predicted label is:plane
# Test case 154: 	 Predicted label is:plane
# Test case 155: 	 Predicted label is:cat
# Test case 156: 	 Predicted label is:plane
# Test case 157: 	 Predicted label is:ship
# Test case 158: 	 Predicted label is:dog
# Test case 159: 	 Predicted label is:deer
# Test case 160: 	 Predicted label is:plane
# Test case 161: 	 Predicted label is:deer
# Test case 162: 	 Predicted label is:frog
# Test case 163: 	 Predicted label is:deer
# Test case 164: 	 Predicted label is:ship
# Test case 165: 	 Predicted label is:bird
# Test case 166: 	 Predicted label is:ship
# Test case 167: 	 Predicted label is:deer
# Test case 168: 	 Predicted label is:frog
# Test case 169: 	 Predicted label is:plane
# Test case 170: 	 Predicted label is:bird
# Test case 171: 	 Predicted label is:deer
# Test case 172: 	 Predicted label is:ship
# Test case 173: 	 Predicted label is:ship
# Test case 174: 	 Predicted label is:deer
# Test case 175: 	 Predicted label is:ship
# Test case 176: 	 Predicted label is:dog
# Test case 177: 	 Predicted label is:deer
# Test case 178: 	 Predicted label is:plane
# Test case 179: 	 Predicted label is:ship
# Test case 180: 	 Predicted label is:ship
# Test case 181: 	 Predicted label is:cat
# Test case 182: 	 Predicted label is:bird
# Test case 183: 	 Predicted label is:deer
# Test case 184: 	 Predicted label is:cat
# Test case 185: 	 Predicted label is:plane
# Test case 186: 	 Predicted label is:bird
# Test case 187: 	 Predicted label is:cat
# Test case 188: 	 Predicted label is:dog
# Test case 189: 	 Predicted label is:plane
# Test case 190: 	 Predicted label is:cat
# Test case 191: 	 Predicted label is:deer
# Test case 192: 	 Predicted label is:deer
# Test case 193: 	 Predicted label is:dog
# Test case 194: 	 Predicted label is:deer
# Test case 195: 	 Predicted label is:deer
# Test case 196: 	 Predicted label is:deer
# Test case 197: 	 Predicted label is:plane
# Test case 198: 	 Predicted label is:horse
# Test case 199: 	 Predicted label is:horse
# Test case 200: 	 Predicted label is:bird
# Test case 201: 	 Predicted label is:deer
# Test case 202: 	 Predicted label is:ship
# Test case 203: 	 Predicted label is:ship
# Test case 204: 	 Predicted label is:bird
# Test case 205: 	 Predicted label is:bird
# Test case 206: 	 Predicted label is:bird
# Test case 207: 	 Predicted label is:bird
# Test case 208: 	 Predicted label is:deer
# Test case 209: 	 Predicted label is:bird
# Test case 210: 	 Predicted label is:frog
# Test case 211: 	 Predicted label is:ship
# Test case 212: 	 Predicted label is:plane
# Test case 213: 	 Predicted label is:horse
# Test case 214: 	 Predicted label is:ship
# Test case 215: 	 Predicted label is:bird
# Test case 216: 	 Predicted label is:bird
# Test case 217: 	 Predicted label is:truck
# Test case 218: 	 Predicted label is:bird
# Test case 219: 	 Predicted label is:deer
# Test case 220: 	 Predicted label is:horse
# Test case 221: 	 Predicted label is:deer
# Test case 222: 	 Predicted label is:horse
# Test case 223: 	 Predicted label is:deer
# Test case 224: 	 Predicted label is:cat
# Test case 225: 	 Predicted label is:frog
# Test case 226: 	 Predicted label is:horse
# Test case 227: 	 Predicted label is:cat
# Test case 228: 	 Predicted label is:dog
# Test case 229: 	 Predicted label is:bird
# Test case 230: 	 Predicted label is:dog
# Test case 231: 	 Predicted label is:car
# Test case 232: 	 Predicted label is:bird
# Test case 233: 	 Predicted label is:dog
# Test case 234: 	 Predicted label is:ship
# Test case 235: 	 Predicted label is:plane
# Test case 236: 	 Predicted label is:frog
# Test case 237: 	 Predicted label is:plane
# Test case 238: 	 Predicted label is:dog
# Test case 239: 	 Predicted label is:dog
# Test case 240: 	 Predicted label is:plane
# Test case 241: 	 Predicted label is:deer
# Test case 242: 	 Predicted label is:deer
# Test case 243: 	 Predicted label is:plane
# Test case 244: 	 Predicted label is:plane
# Test case 245: 	 Predicted label is:dog
# Test case 246: 	 Predicted label is:frog
# Test case 247: 	 Predicted label is:plane
# Test case 248: 	 Predicted label is:frog
# Test case 249: 	 Predicted label is:bird
# Test case 250: 	 Predicted label is:bird
# Test case 251: 	 Predicted label is:dog
# Test case 252: 	 Predicted label is:deer
# Test case 253: 	 Predicted label is:frog
# Test case 254: 	 Predicted label is:frog
# Test case 255: 	 Predicted label is:deer
# Test case 256: 	 Predicted label is:frog
# Test case 257: 	 Predicted label is:ship
# Test case 258: 	 Predicted label is:ship
# Test case 259: 	 Predicted label is:deer
# Test case 260: 	 Predicted label is:ship
# Test case 261: 	 Predicted label is:ship
# Test case 262: 	 Predicted label is:deer
# Test case 263: 	 Predicted label is:bird
# Test case 264: 	 Predicted label is:plane
# Test case 265: 	 Predicted label is:ship
# Test case 266: 	 Predicted label is:ship
# Test case 267: 	 Predicted label is:deer
# Test case 268: 	 Predicted label is:horse
# Test case 269: 	 Predicted label is:plane
# Test case 270: 	 Predicted label is:dog
# Test case 271: 	 Predicted label is:bird
# Test case 272: 	 Predicted label is:frog
# Test case 273: 	 Predicted label is:cat
# Test case 274: 	 Predicted label is:ship
# Test case 275: 	 Predicted label is:frog
# Test case 276: 	 Predicted label is:plane
# Test case 277: 	 Predicted label is:bird
# Test case 278: 	 Predicted label is:dog
# Test case 279: 	 Predicted label is:frog
# Test case 280: 	 Predicted label is:truck
# Test case 281: 	 Predicted label is:deer
# Test case 282: 	 Predicted label is:bird
# Test case 283: 	 Predicted label is:car
# Test case 284: 	 Predicted label is:horse
# Test case 285: 	 Predicted label is:car
# Test case 286: 	 Predicted label is:horse
# Test case 287: 	 Predicted label is:ship
# Test case 288: 	 Predicted label is:dog
# Test case 289: 	 Predicted label is:truck
# Test case 290: 	 Predicted label is:car
# Test case 291: 	 Predicted label is:frog
# Test case 292: 	 Predicted label is:bird
# Test case 293: 	 Predicted label is:car
# Test case 294: 	 Predicted label is:cat
# Test case 295: 	 Predicted label is:frog
# Test case 296: 	 Predicted label is:frog
# Test case 297: 	 Predicted label is:bird
# Test case 298: 	 Predicted label is:bird
# Test case 299: 	 Predicted label is:bird
# Test case 300: 	 Predicted label is:deer
# Test case 301: 	 Predicted label is:bird
# Test case 302: 	 Predicted label is:dog
# Test case 303: 	 Predicted label is:frog
# Test case 304: 	 Predicted label is:deer
# Test case 305: 	 Predicted label is:ship
# Test case 306: 	 Predicted label is:ship
# Test case 307: 	 Predicted label is:bird
# Test case 308: 	 Predicted label is:car
# Test case 309: 	 Predicted label is:bird
# Test case 310: 	 Predicted label is:ship
# Test case 311: 	 Predicted label is:frog
# Test case 312: 	 Predicted label is:ship
# Test case 313: 	 Predicted label is:plane
# Test case 314: 	 Predicted label is:cat
# Test case 315: 	 Predicted label is:plane
# Test case 316: 	 Predicted label is:frog
# Test case 317: 	 Predicted label is:deer
# Test case 318: 	 Predicted label is:cat
# Test case 319: 	 Predicted label is:deer
# Test case 320: 	 Predicted label is:plane
# Test case 321: 	 Predicted label is:cat
# Test case 322: 	 Predicted label is:bird
# Test case 323: 	 Predicted label is:frog
# Test case 324: 	 Predicted label is:frog
# Test case 325: 	 Predicted label is:car
# Test case 326: 	 Predicted label is:deer
# Test case 327: 	 Predicted label is:cat
# Test case 328: 	 Predicted label is:deer
# Test case 329: 	 Predicted label is:bird
# Test case 330: 	 Predicted label is:car
# Test case 331: 	 Predicted label is:truck
# Test case 332: 	 Predicted label is:deer
# Test case 333: 	 Predicted label is:deer
# Test case 334: 	 Predicted label is:bird
# Test case 335: 	 Predicted label is:cat
# Test case 336: 	 Predicted label is:bird
# Test case 337: 	 Predicted label is:ship
# Test case 338: 	 Predicted label is:bird
# Test case 339: 	 Predicted label is:plane
# Test case 340: 	 Predicted label is:dog
# Test case 341: 	 Predicted label is:frog
# Test case 342: 	 Predicted label is:bird
# Test case 343: 	 Predicted label is:dog
# Test case 344: 	 Predicted label is:plane
# Test case 345: 	 Predicted label is:bird
# Test case 346: 	 Predicted label is:cat
# Test case 347: 	 Predicted label is:ship
# Test case 348: 	 Predicted label is:ship
# Test case 349: 	 Predicted label is:truck
# Test case 350: 	 Predicted label is:horse
# Test case 351: 	 Predicted label is:frog
# Test case 352: 	 Predicted label is:car
# Test case 353: 	 Predicted label is:cat
# Test case 354: 	 Predicted label is:bird
# Test case 355: 	 Predicted label is:frog
# Test case 356: 	 Predicted label is:bird
# Test case 357: 	 Predicted label is:dog
# Test case 358: 	 Predicted label is:frog
# Test case 359: 	 Predicted label is:car
# Test case 360: 	 Predicted label is:bird
# Test case 361: 	 Predicted label is:plane
# Test case 362: 	 Predicted label is:ship
# Test case 363: 	 Predicted label is:plane
# Test case 364: 	 Predicted label is:ship
# Test case 365: 	 Predicted label is:plane
# Test case 366: 	 Predicted label is:car
# Test case 367: 	 Predicted label is:car
# Test case 368: 	 Predicted label is:bird
# Test case 369: 	 Predicted label is:ship
# Test case 370: 	 Predicted label is:plane
# Test case 371: 	 Predicted label is:bird
# Test case 372: 	 Predicted label is:plane
# Test case 373: 	 Predicted label is:ship
# Test case 374: 	 Predicted label is:deer
# Test case 375: 	 Predicted label is:horse
# Test case 376: 	 Predicted label is:ship
# Test case 377: 	 Predicted label is:frog
# Test case 378: 	 Predicted label is:cat
# Test case 379: 	 Predicted label is:bird
# Test case 380: 	 Predicted label is:deer
# Test case 381: 	 Predicted label is:truck
# Test case 382: 	 Predicted label is:plane
# Test case 383: 	 Predicted label is:plane
# Test case 384: 	 Predicted label is:deer
# Test case 385: 	 Predicted label is:bird
# Test case 386: 	 Predicted label is:plane
# Test case 387: 	 Predicted label is:bird
# Test case 388: 	 Predicted label is:bird
# Test case 389: 	 Predicted label is:frog
# Test case 390: 	 Predicted label is:plane
# Test case 391: 	 Predicted label is:plane
# Test case 392: 	 Predicted label is:bird
# Test case 393: 	 Predicted label is:frog
# Test case 394: 	 Predicted label is:bird
# Test case 395: 	 Predicted label is:deer
# Test case 396: 	 Predicted label is:bird
# Test case 397: 	 Predicted label is:dog
# Test case 398: 	 Predicted label is:ship
# Test case 399: 	 Predicted label is:cat
# Test case 400: 	 Predicted label is:truck
# Test case 401: 	 Predicted label is:deer
# Test case 402: 	 Predicted label is:deer
# Test case 403: 	 Predicted label is:ship
# Test case 404: 	 Predicted label is:deer
# Test case 405: 	 Predicted label is:deer
# Test case 406: 	 Predicted label is:plane
# Test case 407: 	 Predicted label is:ship
# Test case 408: 	 Predicted label is:plane
# Test case 409: 	 Predicted label is:cat
# Test case 410: 	 Predicted label is:ship
# Test case 411: 	 Predicted label is:truck
# Test case 412: 	 Predicted label is:bird
# Test case 413: 	 Predicted label is:deer
# Test case 414: 	 Predicted label is:cat
# Test case 415: 	 Predicted label is:ship
# Test case 416: 	 Predicted label is:plane
# Test case 417: 	 Predicted label is:dog
# Test case 418: 	 Predicted label is:cat
# Test case 419: 	 Predicted label is:deer
# Test case 420: 	 Predicted label is:frog
# Test case 421: 	 Predicted label is:ship
# Test case 422: 	 Predicted label is:ship
# Test case 423: 	 Predicted label is:bird
# Test case 424: 	 Predicted label is:bird
# Test case 425: 	 Predicted label is:ship
# Test case 426: 	 Predicted label is:frog
# Test case 427: 	 Predicted label is:deer
# Test case 428: 	 Predicted label is:deer
# Test case 429: 	 Predicted label is:cat
# Test case 430: 	 Predicted label is:frog
# Test case 431: 	 Predicted label is:plane
# Test case 432: 	 Predicted label is:bird
# Test case 433: 	 Predicted label is:dog
# Test case 434: 	 Predicted label is:cat
# Test case 435: 	 Predicted label is:deer
# Test case 436: 	 Predicted label is:deer
# Test case 437: 	 Predicted label is:bird
# Test case 438: 	 Predicted label is:bird
# Test case 439: 	 Predicted label is:car
# Test case 440: 	 Predicted label is:truck
# Test case 441: 	 Predicted label is:deer
# Test case 442: 	 Predicted label is:deer
# Test case 443: 	 Predicted label is:ship
# Test case 444: 	 Predicted label is:cat
# Test case 445: 	 Predicted label is:deer
# Test case 446: 	 Predicted label is:ship
# Test case 447: 	 Predicted label is:plane
# Test case 448: 	 Predicted label is:deer
# Test case 449: 	 Predicted label is:bird
# Test case 450: 	 Predicted label is:deer
# Test case 451: 	 Predicted label is:truck
# Test case 452: 	 Predicted label is:horse
# Test case 453: 	 Predicted label is:deer
# Test case 454: 	 Predicted label is:frog
# Test case 455: 	 Predicted label is:bird
# Test case 456: 	 Predicted label is:bird
# Test case 457: 	 Predicted label is:bird
# Test case 458: 	 Predicted label is:frog
# Test case 459: 	 Predicted label is:ship
# Test case 460: 	 Predicted label is:frog
# Test case 461: 	 Predicted label is:cat
# Test case 462: 	 Predicted label is:car
# Test case 463: 	 Predicted label is:deer
# Test case 464: 	 Predicted label is:bird
# Test case 465: 	 Predicted label is:deer
# Test case 466: 	 Predicted label is:deer
# Test case 467: 	 Predicted label is:bird
# Test case 468: 	 Predicted label is:horse
# Test case 469: 	 Predicted label is:ship
# Test case 470: 	 Predicted label is:cat
# Test case 471: 	 Predicted label is:horse
# Test case 472: 	 Predicted label is:ship
# Test case 473: 	 Predicted label is:bird
# Test case 474: 	 Predicted label is:deer
# Test case 475: 	 Predicted label is:dog
# Test case 476: 	 Predicted label is:bird
# Test case 477: 	 Predicted label is:car
# Test case 478: 	 Predicted label is:bird
# Test case 479: 	 Predicted label is:horse
# Test case 480: 	 Predicted label is:ship
# Test case 481: 	 Predicted label is:bird
# Test case 482: 	 Predicted label is:ship
# Test case 483: 	 Predicted label is:deer
# Test case 484: 	 Predicted label is:frog
# Test case 485: 	 Predicted label is:ship
# Test case 486: 	 Predicted label is:truck
# Test case 487: 	 Predicted label is:dog
# Test case 488: 	 Predicted label is:plane
# Test case 489: 	 Predicted label is:plane
# Test case 490: 	 Predicted label is:frog
# Test case 491: 	 Predicted label is:ship
# Test case 492: 	 Predicted label is:ship
# Test case 493: 	 Predicted label is:deer
# Test case 494: 	 Predicted label is:plane
# Test case 495: 	 Predicted label is:ship
# Test case 496: 	 Predicted label is:cat
# Test case 497: 	 Predicted label is:bird
# Test case 498: 	 Predicted label is:bird
# Test case 499: 	 Predicted label is:cat
# Test case 500: 	 Predicted label is:frog
# Test case 501: 	 Predicted label is:bird
# Test case 502: 	 Predicted label is:deer
# Test case 503: 	 Predicted label is:deer
# Test case 504: 	 Predicted label is:truck
# Test case 505: 	 Predicted label is:plane
# Test case 506: 	 Predicted label is:dog
# Test case 507: 	 Predicted label is:deer
# Test case 508: 	 Predicted label is:cat
# Test case 509: 	 Predicted label is:deer
# Test case 510: 	 Predicted label is:plane
# Test case 511: 	 Predicted label is:bird
# Test case 512: 	 Predicted label is:frog
# Test case 513: 	 Predicted label is:ship
# Test case 514: 	 Predicted label is:dog
# Test case 515: 	 Predicted label is:frog
# Test case 516: 	 Predicted label is:plane
# Test case 517: 	 Predicted label is:dog
# Test case 518: 	 Predicted label is:truck
# Test case 519: 	 Predicted label is:ship
# Test case 520: 	 Predicted label is:cat
# Test case 521: 	 Predicted label is:plane
# Test case 522: 	 Predicted label is:plane
# Test case 523: 	 Predicted label is:horse
# Test case 524: 	 Predicted label is:plane
# Test case 525: 	 Predicted label is:cat
# Test case 526: 	 Predicted label is:bird
# Test case 527: 	 Predicted label is:bird
# Test case 528: 	 Predicted label is:plane
# Test case 529: 	 Predicted label is:deer
# Test case 530: 	 Predicted label is:plane
# Test case 531: 	 Predicted label is:truck
# Test case 532: 	 Predicted label is:deer
# Test case 533: 	 Predicted label is:plane
# Test case 534: 	 Predicted label is:frog
# Test case 535: 	 Predicted label is:bird
# Test case 536: 	 Predicted label is:deer
# Test case 537: 	 Predicted label is:frog
# Test case 538: 	 Predicted label is:plane
# Test case 539: 	 Predicted label is:dog
# Test case 540: 	 Predicted label is:ship
# Test case 541: 	 Predicted label is:horse
# Test case 542: 	 Predicted label is:frog
# Test case 543: 	 Predicted label is:horse
# Test case 544: 	 Predicted label is:dog
# Test case 545: 	 Predicted label is:truck
# Test case 546: 	 Predicted label is:car
# Test case 547: 	 Predicted label is:bird
# Test case 548: 	 Predicted label is:deer
# Test case 549: 	 Predicted label is:dog
# Test case 550: 	 Predicted label is:cat
# Test case 551: 	 Predicted label is:dog
# Test case 552: 	 Predicted label is:horse
# Test case 553: 	 Predicted label is:plane
# Test case 554: 	 Predicted label is:ship
# Test case 555: 	 Predicted label is:ship
# Test case 556: 	 Predicted label is:bird
# Test case 557: 	 Predicted label is:deer
# Test case 558: 	 Predicted label is:cat
# Test case 559: 	 Predicted label is:bird
# Test case 560: 	 Predicted label is:bird
# Test case 561: 	 Predicted label is:bird
# Test case 562: 	 Predicted label is:frog
# Test case 563: 	 Predicted label is:deer
# Test case 564: 	 Predicted label is:bird
# Test case 565: 	 Predicted label is:horse
# Test case 566: 	 Predicted label is:plane
# Test case 567: 	 Predicted label is:horse
# Test case 568: 	 Predicted label is:horse
# Test case 569: 	 Predicted label is:bird
# Test case 570: 	 Predicted label is:car
# Test case 571: 	 Predicted label is:horse
# Test case 572: 	 Predicted label is:plane
# Test case 573: 	 Predicted label is:dog
# Test case 574: 	 Predicted label is:frog
# Test case 575: 	 Predicted label is:deer
# Test case 576: 	 Predicted label is:ship
# Test case 577: 	 Predicted label is:ship
# Test case 578: 	 Predicted label is:horse
# Test case 579: 	 Predicted label is:bird
# Test case 580: 	 Predicted label is:deer
# Test case 581: 	 Predicted label is:ship
# Test case 582: 	 Predicted label is:deer
# Test case 583: 	 Predicted label is:ship
# Test case 584: 	 Predicted label is:plane
# Test case 585: 	 Predicted label is:deer
# Test case 586: 	 Predicted label is:bird
# Test case 587: 	 Predicted label is:plane
# Test case 588: 	 Predicted label is:ship
# Test case 589: 	 Predicted label is:plane
# Test case 590: 	 Predicted label is:frog
# Test case 591: 	 Predicted label is:plane
# Test case 592: 	 Predicted label is:bird
# Test case 593: 	 Predicted label is:frog
# Test case 594: 	 Predicted label is:ship
# Test case 595: 	 Predicted label is:deer
# Test case 596: 	 Predicted label is:frog
# Test case 597: 	 Predicted label is:deer
# Test case 598: 	 Predicted label is:frog
# Test case 599: 	 Predicted label is:dog
# Test case 600: 	 Predicted label is:plane
# Test case 601: 	 Predicted label is:bird
# Test case 602: 	 Predicted label is:car
# Test case 603: 	 Predicted label is:bird
# Test case 604: 	 Predicted label is:deer
# Test case 605: 	 Predicted label is:cat
# Test case 606: 	 Predicted label is:cat
# Test case 607: 	 Predicted label is:dog
# Test case 608: 	 Predicted label is:frog
# Test case 609: 	 Predicted label is:car
# Test case 610: 	 Predicted label is:dog
# Test case 611: 	 Predicted label is:dog
# Test case 612: 	 Predicted label is:ship
# Test case 613: 	 Predicted label is:ship
# Test case 614: 	 Predicted label is:deer
# Test case 615: 	 Predicted label is:frog
# Test case 616: 	 Predicted label is:frog
# Test case 617: 	 Predicted label is:bird
# Test case 618: 	 Predicted label is:horse
# Test case 619: 	 Predicted label is:truck
# Test case 620: 	 Predicted label is:bird
# Test case 621: 	 Predicted label is:horse
# Test case 622: 	 Predicted label is:ship
# Test case 623: 	 Predicted label is:bird
# Test case 624: 	 Predicted label is:horse
# Test case 625: 	 Predicted label is:truck
# Test case 626: 	 Predicted label is:cat
# Test case 627: 	 Predicted label is:deer
# Test case 628: 	 Predicted label is:deer
# Test case 629: 	 Predicted label is:dog
# Test case 630: 	 Predicted label is:ship
# Test case 631: 	 Predicted label is:horse
# Test case 632: 	 Predicted label is:cat
# Test case 633: 	 Predicted label is:cat
# Test case 634: 	 Predicted label is:bird
# Test case 635: 	 Predicted label is:bird
# Test case 636: 	 Predicted label is:plane
# Test case 637: 	 Predicted label is:frog
# Test case 638: 	 Predicted label is:ship
# Test case 639: 	 Predicted label is:bird
# Test case 640: 	 Predicted label is:cat
# Test case 641: 	 Predicted label is:frog
# Test case 642: 	 Predicted label is:plane
# Test case 643: 	 Predicted label is:horse
# Test case 644: 	 Predicted label is:plane
# Test case 645: 	 Predicted label is:car
# Test case 646: 	 Predicted label is:cat
# Test case 647: 	 Predicted label is:deer
# Test case 648: 	 Predicted label is:plane
# Test case 649: 	 Predicted label is:bird
# Test case 650: 	 Predicted label is:deer
# Test case 651: 	 Predicted label is:truck
# Test case 652: 	 Predicted label is:frog
# Test case 653: 	 Predicted label is:bird
# Test case 654: 	 Predicted label is:truck
# Test case 655: 	 Predicted label is:bird
# Test case 656: 	 Predicted label is:car
# Test case 657: 	 Predicted label is:frog
# Test case 658: 	 Predicted label is:deer
# Test case 659: 	 Predicted label is:plane
# Test case 660: 	 Predicted label is:plane
# Test case 661: 	 Predicted label is:dog
# Test case 662: 	 Predicted label is:horse
# Test case 663: 	 Predicted label is:frog
# Test case 664: 	 Predicted label is:cat
# Test case 665: 	 Predicted label is:ship
# Test case 666: 	 Predicted label is:frog
# Test case 667: 	 Predicted label is:plane
# Test case 668: 	 Predicted label is:truck
# Test case 669: 	 Predicted label is:bird
# Test case 670: 	 Predicted label is:bird
# Test case 671: 	 Predicted label is:cat
# Test case 672: 	 Predicted label is:horse
# Test case 673: 	 Predicted label is:frog
# Test case 674: 	 Predicted label is:frog
# Test case 675: 	 Predicted label is:deer
# Test case 676: 	 Predicted label is:deer
# Test case 677: 	 Predicted label is:frog
# Test case 678: 	 Predicted label is:plane
# Test case 679: 	 Predicted label is:horse
# Test case 680: 	 Predicted label is:truck
# Test case 681: 	 Predicted label is:frog
# Test case 682: 	 Predicted label is:horse
# Test case 683: 	 Predicted label is:frog
# Test case 684: 	 Predicted label is:cat
# Test case 685: 	 Predicted label is:dog
# Test case 686: 	 Predicted label is:frog
# Test case 687: 	 Predicted label is:dog
# Test case 688: 	 Predicted label is:frog
# Test case 689: 	 Predicted label is:deer
# Test case 690: 	 Predicted label is:deer
# Test case 691: 	 Predicted label is:bird
# Test case 692: 	 Predicted label is:ship
# Test case 693: 	 Predicted label is:deer
# Test case 694: 	 Predicted label is:ship
# Test case 695: 	 Predicted label is:deer
# Test case 696: 	 Predicted label is:ship
# Test case 697: 	 Predicted label is:frog
# Test case 698: 	 Predicted label is:deer
# Test case 699: 	 Predicted label is:deer
# Test case 700: 	 Predicted label is:bird
# Test case 701: 	 Predicted label is:plane
# Test case 702: 	 Predicted label is:frog
# Test case 703: 	 Predicted label is:car
# Test case 704: 	 Predicted label is:deer
# Test case 705: 	 Predicted label is:deer
# Test case 706: 	 Predicted label is:plane
# Test case 707: 	 Predicted label is:frog
# Test case 708: 	 Predicted label is:ship
# Test case 709: 	 Predicted label is:ship
# Test case 710: 	 Predicted label is:dog
# Test case 711: 	 Predicted label is:ship
# Test case 712: 	 Predicted label is:ship
# Test case 713: 	 Predicted label is:horse
# Test case 714: 	 Predicted label is:deer
# Test case 715: 	 Predicted label is:dog
# Test case 716: 	 Predicted label is:bird
# Test case 717: 	 Predicted label is:deer
# Test case 718: 	 Predicted label is:deer
# Test case 719: 	 Predicted label is:bird
# Test case 720: 	 Predicted label is:bird
# Test case 721: 	 Predicted label is:ship
# Test case 722: 	 Predicted label is:horse
# Test case 723: 	 Predicted label is:car
# Test case 724: 	 Predicted label is:ship
# Test case 725: 	 Predicted label is:bird
# Test case 726: 	 Predicted label is:frog
# Test case 727: 	 Predicted label is:dog
# Test case 728: 	 Predicted label is:deer
# Test case 729: 	 Predicted label is:cat
# Test case 730: 	 Predicted label is:deer
# Test case 731: 	 Predicted label is:bird
# Test case 732: 	 Predicted label is:horse
# Test case 733: 	 Predicted label is:bird
# Test case 734: 	 Predicted label is:ship
# Test case 735: 	 Predicted label is:bird
# Test case 736: 	 Predicted label is:ship
# Test case 737: 	 Predicted label is:plane
# Test case 738: 	 Predicted label is:car
# Test case 739: 	 Predicted label is:frog
# Test case 740: 	 Predicted label is:dog
# Test case 741: 	 Predicted label is:cat
# Test case 742: 	 Predicted label is:deer
# Test case 743: 	 Predicted label is:horse
# Test case 744: 	 Predicted label is:deer
# Test case 745: 	 Predicted label is:deer
# Test case 746: 	 Predicted label is:bird
# Test case 747: 	 Predicted label is:dog
# Test case 748: 	 Predicted label is:bird
# Test case 749: 	 Predicted label is:deer
# Test case 750: 	 Predicted label is:deer
# Test case 751: 	 Predicted label is:bird
# Test case 752: 	 Predicted label is:frog
# Test case 753: 	 Predicted label is:frog
# Test case 754: 	 Predicted label is:bird
# Test case 755: 	 Predicted label is:deer
# Test case 756: 	 Predicted label is:frog
# Test case 757: 	 Predicted label is:plane
# Test case 758: 	 Predicted label is:deer
# Test case 759: 	 Predicted label is:car
# Test case 760: 	 Predicted label is:cat
# Test case 761: 	 Predicted label is:dog
# Test case 762: 	 Predicted label is:bird
# Test case 763: 	 Predicted label is:ship
# Test case 764: 	 Predicted label is:plane
# Test case 765: 	 Predicted label is:bird
# Test case 766: 	 Predicted label is:ship
# Test case 767: 	 Predicted label is:plane
# Test case 768: 	 Predicted label is:dog
# Test case 769: 	 Predicted label is:plane
# Test case 770: 	 Predicted label is:plane
# Test case 771: 	 Predicted label is:plane
# Test case 772: 	 Predicted label is:dog
# Test case 773: 	 Predicted label is:dog
# Test case 774: 	 Predicted label is:bird
# Test case 775: 	 Predicted label is:deer
# Test case 776: 	 Predicted label is:truck
# Test case 777: 	 Predicted label is:deer
# Test case 778: 	 Predicted label is:bird
# Test case 779: 	 Predicted label is:frog
# Test case 780: 	 Predicted label is:deer
# Test case 781: 	 Predicted label is:frog
# Test case 782: 	 Predicted label is:deer
# Test case 783: 	 Predicted label is:deer
# Test case 784: 	 Predicted label is:frog
# Test case 785: 	 Predicted label is:ship
# Test case 786: 	 Predicted label is:cat
# Test case 787: 	 Predicted label is:plane
# Test case 788: 	 Predicted label is:ship
# Test case 789: 	 Predicted label is:plane
# Test case 790: 	 Predicted label is:bird
# Test case 791: 	 Predicted label is:plane
# Test case 792: 	 Predicted label is:plane
# Test case 793: 	 Predicted label is:cat
# Test case 794: 	 Predicted label is:bird
# Test case 795: 	 Predicted label is:ship
# Test case 796: 	 Predicted label is:deer
# Test case 797: 	 Predicted label is:bird
# Test case 798: 	 Predicted label is:frog
# Test case 799: 	 Predicted label is:bird
# Test case 800: 	 Predicted label is:horse
# Test case 801: 	 Predicted label is:ship
# Test case 802: 	 Predicted label is:plane
# Test case 803: 	 Predicted label is:deer
# Test case 804: 	 Predicted label is:deer
# Test case 805: 	 Predicted label is:deer
# Test case 806: 	 Predicted label is:ship
# Test case 807: 	 Predicted label is:deer
# Test case 808: 	 Predicted label is:deer
# Test case 809: 	 Predicted label is:bird
# Test case 810: 	 Predicted label is:cat
# Test case 811: 	 Predicted label is:dog
# Test case 812: 	 Predicted label is:horse
# Test case 813: 	 Predicted label is:bird
# Test case 814: 	 Predicted label is:ship
# Test case 815: 	 Predicted label is:ship
# Test case 816: 	 Predicted label is:frog
# Test case 817: 	 Predicted label is:deer
# Test case 818: 	 Predicted label is:frog
# Test case 819: 	 Predicted label is:bird
# Test case 820: 	 Predicted label is:truck
# Test case 821: 	 Predicted label is:bird
# Test case 822: 	 Predicted label is:deer
# Test case 823: 	 Predicted label is:ship
# Test case 824: 	 Predicted label is:deer
# Test case 825: 	 Predicted label is:plane
# Test case 826: 	 Predicted label is:horse
# Test case 827: 	 Predicted label is:deer
# Test case 828: 	 Predicted label is:frog
# Test case 829: 	 Predicted label is:deer
# Test case 830: 	 Predicted label is:ship
# Test case 831: 	 Predicted label is:cat
# Test case 832: 	 Predicted label is:plane
# Test case 833: 	 Predicted label is:bird
# Test case 834: 	 Predicted label is:deer
# Test case 835: 	 Predicted label is:deer
# Test case 836: 	 Predicted label is:ship
# Test case 837: 	 Predicted label is:dog
# Test case 838: 	 Predicted label is:deer
# Test case 839: 	 Predicted label is:bird
# Test case 840: 	 Predicted label is:horse
# Test case 841: 	 Predicted label is:frog
# Test case 842: 	 Predicted label is:deer
# Test case 843: 	 Predicted label is:deer
# Test case 844: 	 Predicted label is:frog
# Test case 845: 	 Predicted label is:cat
# Test case 846: 	 Predicted label is:deer
# Test case 847: 	 Predicted label is:plane
# Test case 848: 	 Predicted label is:horse
# Test case 849: 	 Predicted label is:cat
# Test case 850: 	 Predicted label is:cat
# Test case 851: 	 Predicted label is:truck
# Test case 852: 	 Predicted label is:ship
# Test case 853: 	 Predicted label is:plane
# Test case 854: 	 Predicted label is:bird
# Test case 855: 	 Predicted label is:ship
# Test case 856: 	 Predicted label is:horse
# Test case 857: 	 Predicted label is:plane
# Test case 858: 	 Predicted label is:dog
# Test case 859: 	 Predicted label is:cat
# Test case 860: 	 Predicted label is:deer
# Test case 861: 	 Predicted label is:bird
# Test case 862: 	 Predicted label is:frog
# Test case 863: 	 Predicted label is:plane
# Test case 864: 	 Predicted label is:plane
# Test case 865: 	 Predicted label is:car
# Test case 866: 	 Predicted label is:cat
# Test case 867: 	 Predicted label is:frog
# Test case 868: 	 Predicted label is:bird
# Test case 869: 	 Predicted label is:plane
# Test case 870: 	 Predicted label is:truck
# Test case 871: 	 Predicted label is:cat
# Test case 872: 	 Predicted label is:deer
# Test case 873: 	 Predicted label is:bird
# Test case 874: 	 Predicted label is:bird
# Test case 875: 	 Predicted label is:plane
# Test case 876: 	 Predicted label is:deer
# Test case 877: 	 Predicted label is:bird
# Test case 878: 	 Predicted label is:ship
# Test case 879: 	 Predicted label is:bird
# Test case 880: 	 Predicted label is:ship
# Test case 881: 	 Predicted label is:frog
# Test case 882: 	 Predicted label is:ship
# Test case 883: 	 Predicted label is:plane
# Test case 884: 	 Predicted label is:truck
# Test case 885: 	 Predicted label is:plane
# Test case 886: 	 Predicted label is:ship
# Test case 887: 	 Predicted label is:bird
# Test case 888: 	 Predicted label is:deer
# Test case 889: 	 Predicted label is:deer
# Test case 890: 	 Predicted label is:ship
# Test case 891: 	 Predicted label is:bird
# Test case 892: 	 Predicted label is:horse
# Test case 893: 	 Predicted label is:bird
# Test case 894: 	 Predicted label is:ship
# Test case 895: 	 Predicted label is:plane
# Test case 896: 	 Predicted label is:bird
# Test case 897: 	 Predicted label is:dog
# Test case 898: 	 Predicted label is:bird
# Test case 899: 	 Predicted label is:dog
# Test case 900: 	 Predicted label is:bird
# Test case 901: 	 Predicted label is:bird
# Test case 902: 	 Predicted label is:deer
# Test case 903: 	 Predicted label is:dog
# Test case 904: 	 Predicted label is:ship
# Test case 905: 	 Predicted label is:bird
# Test case 906: 	 Predicted label is:truck
# Test case 907: 	 Predicted label is:deer
# Test case 908: 	 Predicted label is:ship
# Test case 909: 	 Predicted label is:cat
# Test case 910: 	 Predicted label is:deer
# Test case 911: 	 Predicted label is:dog
# Test case 912: 	 Predicted label is:cat
# Test case 913: 	 Predicted label is:bird
# Test case 914: 	 Predicted label is:cat
# Test case 915: 	 Predicted label is:deer
# Test case 916: 	 Predicted label is:bird
# Test case 917: 	 Predicted label is:ship
# Test case 918: 	 Predicted label is:ship
# Test case 919: 	 Predicted label is:bird
# Test case 920: 	 Predicted label is:bird
# Test case 921: 	 Predicted label is:car
# Test case 922: 	 Predicted label is:truck
# Test case 923: 	 Predicted label is:frog
# Test case 924: 	 Predicted label is:dog
# Test case 925: 	 Predicted label is:cat
# Test case 926: 	 Predicted label is:ship
# Test case 927: 	 Predicted label is:frog
# Test case 928: 	 Predicted label is:bird
# Test case 929: 	 Predicted label is:ship
# Test case 930: 	 Predicted label is:deer
# Test case 931: 	 Predicted label is:bird
# Test case 932: 	 Predicted label is:bird
# Test case 933: 	 Predicted label is:frog
# Test case 934: 	 Predicted label is:ship
# Test case 935: 	 Predicted label is:plane
# Test case 936: 	 Predicted label is:plane
# Test case 937: 	 Predicted label is:plane
# Test case 938: 	 Predicted label is:deer
# Test case 939: 	 Predicted label is:cat
# Test case 940: 	 Predicted label is:frog
# Test case 941: 	 Predicted label is:deer
# Test case 942: 	 Predicted label is:horse
# Test case 943: 	 Predicted label is:bird
# Test case 944: 	 Predicted label is:plane
# Test case 945: 	 Predicted label is:cat
# Test case 946: 	 Predicted label is:plane
# Test case 947: 	 Predicted label is:frog
# Test case 948: 	 Predicted label is:cat
# Test case 949: 	 Predicted label is:deer
# Test case 950: 	 Predicted label is:ship
# Test case 951: 	 Predicted label is:truck
# Test case 952: 	 Predicted label is:deer
# Test case 953: 	 Predicted label is:horse
# Test case 954: 	 Predicted label is:bird
# Test case 955: 	 Predicted label is:horse
# Test case 956: 	 Predicted label is:bird
# Test case 957: 	 Predicted label is:ship
# Test case 958: 	 Predicted label is:bird
# Test case 959: 	 Predicted label is:ship
# Test case 960: 	 Predicted label is:cat
# Test case 961: 	 Predicted label is:deer
# Test case 962: 	 Predicted label is:bird
# Test case 963: 	 Predicted label is:dog
# Test case 964: 	 Predicted label is:frog
# Test case 965: 	 Predicted label is:bird
# Test case 966: 	 Predicted label is:frog
# Test case 967: 	 Predicted label is:car
# Test case 968: 	 Predicted label is:car
# Test case 969: 	 Predicted label is:truck
# Test case 970: 	 Predicted label is:car
# Test case 971: 	 Predicted label is:frog
# Test case 972: 	 Predicted label is:deer
# Test case 973: 	 Predicted label is:frog
# Test case 974: 	 Predicted label is:bird
# Test case 975: 	 Predicted label is:plane
# Test case 976: 	 Predicted label is:frog
# Test case 977: 	 Predicted label is:ship
# Test case 978: 	 Predicted label is:frog
# Test case 979: 	 Predicted label is:horse
# Test case 980: 	 Predicted label is:deer
# Test case 981: 	 Predicted label is:truck
# Test case 982: 	 Predicted label is:cat
# Test case 983: 	 Predicted label is:deer
# Test case 984: 	 Predicted label is:deer
# Test case 985: 	 Predicted label is:plane
# Test case 986: 	 Predicted label is:dog
# Test case 987: 	 Predicted label is:plane
# Test case 988: 	 Predicted label is:deer
# Test case 989: 	 Predicted label is:plane
# Test case 990: 	 Predicted label is:deer
# Test case 991: 	 Predicted label is:deer
# Test case 992: 	 Predicted label is:ship
# Test case 993: 	 Predicted label is:horse
# Test case 994: 	 Predicted label is:cat
# Test case 995: 	 Predicted label is:dog
# Test case 996: 	 Predicted label is:bird
# Test case 997: 	 Predicted label is:truck
# Test case 998: 	 Predicted label is:frog
# Test case 999: 	 Predicted label is:ship
# Test case 1000: 	 Predicted label is:dog
# Test case 1001: 	 Predicted label is:frog
# Test case 1002: 	 Predicted label is:ship
# Test case 1003: 	 Predicted label is:plane
# Test case 1004: 	 Predicted label is:ship
# Test case 1005: 	 Predicted label is:plane
# Test case 1006: 	 Predicted label is:frog
# Test case 1007: 	 Predicted label is:bird
# Test case 1008: 	 Predicted label is:frog
# Test case 1009: 	 Predicted label is:frog
# Test case 1010: 	 Predicted label is:plane
# Test case 1011: 	 Predicted label is:ship
# Test case 1012: 	 Predicted label is:bird
# Test case 1013: 	 Predicted label is:car
# Test case 1014: 	 Predicted label is:deer
# Test case 1015: 	 Predicted label is:bird
# Test case 1016: 	 Predicted label is:cat
# Test case 1017: 	 Predicted label is:frog
# Test case 1018: 	 Predicted label is:plane
# Test case 1019: 	 Predicted label is:plane
# Test case 1020: 	 Predicted label is:plane
# Test case 1021: 	 Predicted label is:bird
# Test case 1022: 	 Predicted label is:plane
# Test case 1023: 	 Predicted label is:ship
# Test case 1024: 	 Predicted label is:frog
# Test case 1025: 	 Predicted label is:dog
# Test case 1026: 	 Predicted label is:bird
# Test case 1027: 	 Predicted label is:horse
# Test case 1028: 	 Predicted label is:cat
# Test case 1029: 	 Predicted label is:frog
# Test case 1030: 	 Predicted label is:bird
# Test case 1031: 	 Predicted label is:plane
# Test case 1032: 	 Predicted label is:deer
# Test case 1033: 	 Predicted label is:ship
# Test case 1034: 	 Predicted label is:ship
# Test case 1035: 	 Predicted label is:bird
# Test case 1036: 	 Predicted label is:deer
# Test case 1037: 	 Predicted label is:deer
# Test case 1038: 	 Predicted label is:ship
# Test case 1039: 	 Predicted label is:bird
# Test case 1040: 	 Predicted label is:frog
# Test case 1041: 	 Predicted label is:bird
# Test case 1042: 	 Predicted label is:frog
# Test case 1043: 	 Predicted label is:bird
# Test case 1044: 	 Predicted label is:ship
# Test case 1045: 	 Predicted label is:dog
# Test case 1046: 	 Predicted label is:bird
# Test case 1047: 	 Predicted label is:plane
# Test case 1048: 	 Predicted label is:bird
# Test case 1049: 	 Predicted label is:frog
# Test case 1050: 	 Predicted label is:plane
# Test case 1051: 	 Predicted label is:plane
# Test case 1052: 	 Predicted label is:plane
# Test case 1053: 	 Predicted label is:frog
# Test case 1054: 	 Predicted label is:cat
# Test case 1055: 	 Predicted label is:ship
# Test case 1056: 	 Predicted label is:cat
# Test case 1057: 	 Predicted label is:cat
# Test case 1058: 	 Predicted label is:frog
# Test case 1059: 	 Predicted label is:ship
# Test case 1060: 	 Predicted label is:ship
# Test case 1061: 	 Predicted label is:frog
# Test case 1062: 	 Predicted label is:frog
# Test case 1063: 	 Predicted label is:deer
# Test case 1064: 	 Predicted label is:cat
# Test case 1065: 	 Predicted label is:horse
# Test case 1066: 	 Predicted label is:frog
# Test case 1067: 	 Predicted label is:deer
# Test case 1068: 	 Predicted label is:ship
# Test case 1069: 	 Predicted label is:frog
# Test case 1070: 	 Predicted label is:bird
# Test case 1071: 	 Predicted label is:deer
# Test case 1072: 	 Predicted label is:ship
# Test case 1073: 	 Predicted label is:horse
# Test case 1074: 	 Predicted label is:cat
# Test case 1075: 	 Predicted label is:ship
# Test case 1076: 	 Predicted label is:plane
# Test case 1077: 	 Predicted label is:plane
# Test case 1078: 	 Predicted label is:frog
# Test case 1079: 	 Predicted label is:frog
# Test case 1080: 	 Predicted label is:cat
# Test case 1081: 	 Predicted label is:cat
# Test case 1082: 	 Predicted label is:ship
# Test case 1083: 	 Predicted label is:cat
# Test case 1084: 	 Predicted label is:plane
# Test case 1085: 	 Predicted label is:deer
# Test case 1086: 	 Predicted label is:deer
# Test case 1087: 	 Predicted label is:frog
# Test case 1088: 	 Predicted label is:frog
# Test case 1089: 	 Predicted label is:bird
# Test case 1090: 	 Predicted label is:ship
# Test case 1091: 	 Predicted label is:plane
# Test case 1092: 	 Predicted label is:frog
# Test case 1093: 	 Predicted label is:plane
# Test case 1094: 	 Predicted label is:dog
# Test case 1095: 	 Predicted label is:bird
# Test case 1096: 	 Predicted label is:horse
# Test case 1097: 	 Predicted label is:bird
# Test case 1098: 	 Predicted label is:deer
# Test case 1099: 	 Predicted label is:bird
# Test case 1100: 	 Predicted label is:ship
# Test case 1101: 	 Predicted label is:ship
# Test case 1102: 	 Predicted label is:deer
# Test case 1103: 	 Predicted label is:bird
# Test case 1104: 	 Predicted label is:horse
# Test case 1105: 	 Predicted label is:bird
# Test case 1106: 	 Predicted label is:horse
# Test case 1107: 	 Predicted label is:bird
# Test case 1108: 	 Predicted label is:deer
# Test case 1109: 	 Predicted label is:ship
# Test case 1110: 	 Predicted label is:bird
# Test case 1111: 	 Predicted label is:ship
# Test case 1112: 	 Predicted label is:dog
# Test case 1113: 	 Predicted label is:ship
# Test case 1114: 	 Predicted label is:ship
# Test case 1115: 	 Predicted label is:ship
# Test case 1116: 	 Predicted label is:cat
# Test case 1117: 	 Predicted label is:plane
# Test case 1118: 	 Predicted label is:dog
# Test case 1119: 	 Predicted label is:ship
# Test case 1120: 	 Predicted label is:plane
# Test case 1121: 	 Predicted label is:cat
# Test case 1122: 	 Predicted label is:car
# Test case 1123: 	 Predicted label is:cat
# Test case 1124: 	 Predicted label is:deer
# Test case 1125: 	 Predicted label is:bird
# Test case 1126: 	 Predicted label is:bird
# Test case 1127: 	 Predicted label is:ship
# Test case 1128: 	 Predicted label is:bird
# Test case 1129: 	 Predicted label is:bird
# Test case 1130: 	 Predicted label is:ship
# Test case 1131: 	 Predicted label is:ship
# Test case 1132: 	 Predicted label is:frog
# Test case 1133: 	 Predicted label is:frog
# Test case 1134: 	 Predicted label is:plane
# Test case 1135: 	 Predicted label is:cat
# Test case 1136: 	 Predicted label is:deer
# Test case 1137: 	 Predicted label is:deer
# Test case 1138: 	 Predicted label is:frog
# Test case 1139: 	 Predicted label is:ship
# Test case 1140: 	 Predicted label is:frog
# Test case 1141: 	 Predicted label is:ship
# Test case 1142: 	 Predicted label is:ship
# Test case 1143: 	 Predicted label is:frog
# Test case 1144: 	 Predicted label is:car
# Test case 1145: 	 Predicted label is:frog
# Test case 1146: 	 Predicted label is:deer
# Test case 1147: 	 Predicted label is:cat
# Test case 1148: 	 Predicted label is:bird
# Test case 1149: 	 Predicted label is:bird
# Test case 1150: 	 Predicted label is:horse
# Test case 1151: 	 Predicted label is:deer
# Test case 1152: 	 Predicted label is:bird
# Test case 1153: 	 Predicted label is:ship
# Test case 1154: 	 Predicted label is:bird
# Test case 1155: 	 Predicted label is:cat
# Test case 1156: 	 Predicted label is:deer
# Test case 1157: 	 Predicted label is:deer
# Test case 1158: 	 Predicted label is:bird
# Test case 1159: 	 Predicted label is:ship
# Test case 1160: 	 Predicted label is:plane
# Test case 1161: 	 Predicted label is:bird
# Test case 1162: 	 Predicted label is:bird
# Test case 1163: 	 Predicted label is:plane
# Test case 1164: 	 Predicted label is:plane
# Test case 1165: 	 Predicted label is:ship
# Test case 1166: 	 Predicted label is:dog
# Test case 1167: 	 Predicted label is:bird
# ...
# Test case 9621: 	 Predicted label is:frog
# Test case 9622: 	 Predicted label is:deer
# Test case 9623: 	 Predicted label is:cat
# Test case 9624: 	 Predicted label is:plane
# Test case 9625: 	 Predicted label is:plane
# Test case 9626: 	 Predicted label is:ship
# Test case 9627: 	 Predicted label is:bird
# Test case 9628: 	 Predicted label is:truck
# Test case 9629: 	 Predicted label is:ship
# Test case 9630: 	 Predicted label is:frog
# Test case 9631: 	 Predicted label is:plane
# Test case 9632: 	 Predicted label is:bird
# Test case 9633: 	 Predicted label is:bird
# Test case 9634: 	 Predicted label is:ship
# Test case 9635: 	 Predicted label is:frog
# Test case 9636: 	 Predicted label is:deer
# Test case 9637: 	 Predicted label is:deer
# Test case 9638: 	 Predicted label is:bird
# Test case 9639: 	 Predicted label is:bird
# Test case 9640: 	 Predicted label is:dog
# Test case 9641: 	 Predicted label is:bird
# Test case 9642: 	 Predicted label is:bird
# Test case 9643: 	 Predicted label is:car
# Test case 9644: 	 Predicted label is:truck
# Test case 9645: 	 Predicted label is:car
# Test case 9646: 	 Predicted label is:frog
# Test case 9647: 	 Predicted label is:cat
# Test case 9648: 	 Predicted label is:cat
# Test case 9649: 	 Predicted label is:dog
# Test case 9650: 	 Predicted label is:ship
# Test case 9651: 	 Predicted label is:horse
# Test case 9652: 	 Predicted label is:ship
# Test case 9653: 	 Predicted label is:cat
# Test case 9654: 	 Predicted label is:dog
# Test case 9655: 	 Predicted label is:ship
# Test case 9656: 	 Predicted label is:ship
# Test case 9657: 	 Predicted label is:frog
# Test case 9658: 	 Predicted label is:frog
# Test case 9659: 	 Predicted label is:horse
# Test case 9660: 	 Predicted label is:frog
# Test case 9661: 	 Predicted label is:deer
# Test case 9662: 	 Predicted label is:car
# Test case 9663: 	 Predicted label is:ship
# Test case 9664: 	 Predicted label is:ship
# Test case 9665: 	 Predicted label is:dog
# Test case 9666: 	 Predicted label is:deer
# Test case 9667: 	 Predicted label is:truck
# Test case 9668: 	 Predicted label is:deer
# Test case 9669: 	 Predicted label is:car
# Test case 9670: 	 Predicted label is:ship
# Test case 9671: 	 Predicted label is:plane
# Test case 9672: 	 Predicted label is:horse
# Test case 9673: 	 Predicted label is:plane
# Test case 9674: 	 Predicted label is:car
# Test case 9675: 	 Predicted label is:bird
# Test case 9676: 	 Predicted label is:bird
# Test case 9677: 	 Predicted label is:frog
# Test case 9678: 	 Predicted label is:deer
# Test case 9679: 	 Predicted label is:cat
# Test case 9680: 	 Predicted label is:plane
# Test case 9681: 	 Predicted label is:plane
# Test case 9682: 	 Predicted label is:frog
# Test case 9683: 	 Predicted label is:deer
# Test case 9684: 	 Predicted label is:frog
# Test case 9685: 	 Predicted label is:plane
# Test case 9686: 	 Predicted label is:frog
# Test case 9687: 	 Predicted label is:bird
# Test case 9688: 	 Predicted label is:deer
# Test case 9689: 	 Predicted label is:plane
# Test case 9690: 	 Predicted label is:deer
# Test case 9691: 	 Predicted label is:plane
# Test case 9692: 	 Predicted label is:truck
# Test case 9693: 	 Predicted label is:bird
# Test case 9694: 	 Predicted label is:cat
# Test case 9695: 	 Predicted label is:plane
# Test case 9696: 	 Predicted label is:ship
# Test case 9697: 	 Predicted label is:horse
# Test case 9698: 	 Predicted label is:horse
# Test case 9699: 	 Predicted label is:car
# Test case 9700: 	 Predicted label is:bird
# Test case 9701: 	 Predicted label is:deer
# Test case 9702: 	 Predicted label is:horse
# Test case 9703: 	 Predicted label is:deer
# Test case 9704: 	 Predicted label is:bird
# Test case 9705: 	 Predicted label is:bird
# Test case 9706: 	 Predicted label is:frog
# Test case 9707: 	 Predicted label is:plane
# Test case 9708: 	 Predicted label is:deer
# Test case 9709: 	 Predicted label is:ship
# Test case 9710: 	 Predicted label is:plane
# Test case 9711: 	 Predicted label is:deer
# Test case 9712: 	 Predicted label is:cat
# Test case 9713: 	 Predicted label is:ship
# Test case 9714: 	 Predicted label is:car
# Test case 9715: 	 Predicted label is:cat
# Test case 9716: 	 Predicted label is:frog
# Test case 9717: 	 Predicted label is:plane
# Test case 9718: 	 Predicted label is:ship
# Test case 9719: 	 Predicted label is:ship
# Test case 9720: 	 Predicted label is:deer
# Test case 9721: 	 Predicted label is:frog
# Test case 9722: 	 Predicted label is:deer
# Test case 9723: 	 Predicted label is:cat
# Test case 9724: 	 Predicted label is:bird
# Test case 9725: 	 Predicted label is:plane
# Test case 9726: 	 Predicted label is:ship
# Test case 9727: 	 Predicted label is:plane
# Test case 9728: 	 Predicted label is:frog
# Test case 9729: 	 Predicted label is:deer
# Test case 9730: 	 Predicted label is:frog
# Test case 9731: 	 Predicted label is:deer
# Test case 9732: 	 Predicted label is:bird
# Test case 9733: 	 Predicted label is:horse
# Test case 9734: 	 Predicted label is:frog
# Test case 9735: 	 Predicted label is:ship
# Test case 9736: 	 Predicted label is:ship
# Test case 9737: 	 Predicted label is:deer
# Test case 9738: 	 Predicted label is:frog
# Test case 9739: 	 Predicted label is:plane
# Test case 9740: 	 Predicted label is:bird
# Test case 9741: 	 Predicted label is:deer
# Test case 9742: 	 Predicted label is:dog
# Test case 9743: 	 Predicted label is:car
# Test case 9744: 	 Predicted label is:truck
# Test case 9745: 	 Predicted label is:deer
# Test case 9746: 	 Predicted label is:plane
# Test case 9747: 	 Predicted label is:plane
# Test case 9748: 	 Predicted label is:horse
# Test case 9749: 	 Predicted label is:plane
# Test case 9750: 	 Predicted label is:frog
# Test case 9751: 	 Predicted label is:bird
# Test case 9752: 	 Predicted label is:plane
# Test case 9753: 	 Predicted label is:deer
# Test case 9754: 	 Predicted label is:car
# Test case 9755: 	 Predicted label is:bird
# Test case 9756: 	 Predicted label is:bird
# Test case 9757: 	 Predicted label is:deer
# Test case 9758: 	 Predicted label is:frog
# Test case 9759: 	 Predicted label is:bird
# Test case 9760: 	 Predicted label is:plane
# Test case 9761: 	 Predicted label is:deer
# Test case 9762: 	 Predicted label is:deer
# Test case 9763: 	 Predicted label is:frog
# Test case 9764: 	 Predicted label is:bird
# Test case 9765: 	 Predicted label is:deer
# Test case 9766: 	 Predicted label is:plane
# Test case 9767: 	 Predicted label is:bird
# Test case 9768: 	 Predicted label is:horse
# Test case 9769: 	 Predicted label is:ship
# Test case 9770: 	 Predicted label is:dog
# Test case 9771: 	 Predicted label is:deer
# Test case 9772: 	 Predicted label is:deer
# Test case 9773: 	 Predicted label is:truck
# Test case 9774: 	 Predicted label is:deer
# Test case 9775: 	 Predicted label is:ship
# Test case 9776: 	 Predicted label is:bird
# Test case 9777: 	 Predicted label is:truck
# Test case 9778: 	 Predicted label is:dog
# Test case 9779: 	 Predicted label is:deer
# Test case 9780: 	 Predicted label is:deer
# Test case 9781: 	 Predicted label is:frog
# Test case 9782: 	 Predicted label is:bird
# Test case 9783: 	 Predicted label is:deer
# Test case 9784: 	 Predicted label is:plane
# Test case 9785: 	 Predicted label is:ship
# Test case 9786: 	 Predicted label is:horse
# Test case 9787: 	 Predicted label is:plane
# Test case 9788: 	 Predicted label is:car
# Test case 9789: 	 Predicted label is:frog
# Test case 9790: 	 Predicted label is:ship
# Test case 9791: 	 Predicted label is:cat
# Test case 9792: 	 Predicted label is:cat
# Test case 9793: 	 Predicted label is:ship
# Test case 9794: 	 Predicted label is:bird
# Test case 9795: 	 Predicted label is:plane
# Test case 9796: 	 Predicted label is:plane
# Test case 9797: 	 Predicted label is:bird
# Test case 9798: 	 Predicted label is:dog
# Test case 9799: 	 Predicted label is:cat
# Test case 9800: 	 Predicted label is:car
# Test case 9801: 	 Predicted label is:frog
# Test case 9802: 	 Predicted label is:plane
# Test case 9803: 	 Predicted label is:dog
# Test case 9804: 	 Predicted label is:dog
# Test case 9805: 	 Predicted label is:plane
# Test case 9806: 	 Predicted label is:ship
# Test case 9807: 	 Predicted label is:bird
# Test case 9808: 	 Predicted label is:car
# Test case 9809: 	 Predicted label is:deer
# Test case 9810: 	 Predicted label is:deer
# Test case 9811: 	 Predicted label is:car
# Test case 9812: 	 Predicted label is:frog
# Test case 9813: 	 Predicted label is:ship
# Test case 9814: 	 Predicted label is:ship
# Test case 9815: 	 Predicted label is:deer
# Test case 9816: 	 Predicted label is:ship
# Test case 9817: 	 Predicted label is:horse
# Test case 9818: 	 Predicted label is:ship
# Test case 9819: 	 Predicted label is:frog
# Test case 9820: 	 Predicted label is:ship
# Test case 9821: 	 Predicted label is:bird
# Test case 9822: 	 Predicted label is:plane
# Test case 9823: 	 Predicted label is:ship
# Test case 9824: 	 Predicted label is:plane
# Test case 9825: 	 Predicted label is:bird
# Test case 9826: 	 Predicted label is:plane
# Test case 9827: 	 Predicted label is:bird
# Test case 9828: 	 Predicted label is:ship
# Test case 9829: 	 Predicted label is:horse
# Test case 9830: 	 Predicted label is:ship
# Test case 9831: 	 Predicted label is:bird
# Test case 9832: 	 Predicted label is:bird
# Test case 9833: 	 Predicted label is:frog
# Test case 9834: 	 Predicted label is:ship
# Test case 9835: 	 Predicted label is:cat
# Test case 9836: 	 Predicted label is:plane
# Test case 9837: 	 Predicted label is:bird
# Test case 9838: 	 Predicted label is:cat
# Test case 9839: 	 Predicted label is:deer
# Test case 9840: 	 Predicted label is:cat
# Test case 9841: 	 Predicted label is:plane
# Test case 9842: 	 Predicted label is:frog
# Test case 9843: 	 Predicted label is:ship
# Test case 9844: 	 Predicted label is:ship
# Test case 9845: 	 Predicted label is:frog
# Test case 9846: 	 Predicted label is:ship
# Test case 9847: 	 Predicted label is:plane
# Test case 9848: 	 Predicted label is:plane
# Test case 9849: 	 Predicted label is:plane
# Test case 9850: 	 Predicted label is:deer
# Test case 9851: 	 Predicted label is:dog
# Test case 9852: 	 Predicted label is:plane
# Test case 9853: 	 Predicted label is:bird
# Test case 9854: 	 Predicted label is:frog
# Test case 9855: 	 Predicted label is:frog
# Test case 9856: 	 Predicted label is:ship
# Test case 9857: 	 Predicted label is:plane
# Test case 9858: 	 Predicted label is:bird
# Test case 9859: 	 Predicted label is:deer
# Test case 9860: 	 Predicted label is:ship
# Test case 9861: 	 Predicted label is:bird
# Test case 9862: 	 Predicted label is:cat
# Test case 9863: 	 Predicted label is:frog
# Test case 9864: 	 Predicted label is:ship
# Test case 9865: 	 Predicted label is:plane
# Test case 9866: 	 Predicted label is:ship
# Test case 9867: 	 Predicted label is:ship
# Test case 9868: 	 Predicted label is:ship
# Test case 9869: 	 Predicted label is:deer
# Test case 9870: 	 Predicted label is:ship
# Test case 9871: 	 Predicted label is:plane
# Test case 9872: 	 Predicted label is:deer
# Test case 9873: 	 Predicted label is:frog
# Test case 9874: 	 Predicted label is:bird
# Test case 9875: 	 Predicted label is:ship
# Test case 9876: 	 Predicted label is:plane
# Test case 9877: 	 Predicted label is:bird
# Test case 9878: 	 Predicted label is:frog
# Test case 9879: 	 Predicted label is:ship
# Test case 9880: 	 Predicted label is:dog
# Test case 9881: 	 Predicted label is:car
# Test case 9882: 	 Predicted label is:ship
# Test case 9883: 	 Predicted label is:cat
# Test case 9884: 	 Predicted label is:cat
# Test case 9885: 	 Predicted label is:ship
# Test case 9886: 	 Predicted label is:bird
# Test case 9887: 	 Predicted label is:car
# Test case 9888: 	 Predicted label is:plane
# Test case 9889: 	 Predicted label is:bird
# Test case 9890: 	 Predicted label is:ship
# Test case 9891: 	 Predicted label is:bird
# Test case 9892: 	 Predicted label is:deer
# Test case 9893: 	 Predicted label is:bird
# Test case 9894: 	 Predicted label is:deer
# Test case 9895: 	 Predicted label is:bird
# Test case 9896: 	 Predicted label is:deer
# Test case 9897: 	 Predicted label is:ship
# Test case 9898: 	 Predicted label is:plane
# Test case 9899: 	 Predicted label is:horse
# Test case 9900: 	 Predicted label is:plane
# Test case 9901: 	 Predicted label is:deer
# Test case 9902: 	 Predicted label is:deer
# Test case 9903: 	 Predicted label is:deer
# Test case 9904: 	 Predicted label is:ship
# Test case 9905: 	 Predicted label is:car
# Test case 9906: 	 Predicted label is:truck
# Test case 9907: 	 Predicted label is:car
# Test case 9908: 	 Predicted label is:ship
# Test case 9909: 	 Predicted label is:car
# Test case 9910: 	 Predicted label is:plane
# Test case 9911: 	 Predicted label is:deer
# Test case 9912: 	 Predicted label is:ship
# Test case 9913: 	 Predicted label is:bird
# Test case 9914: 	 Predicted label is:ship
# Test case 9915: 	 Predicted label is:frog
# Test case 9916: 	 Predicted label is:car
# Test case 9917: 	 Predicted label is:plane
# Test case 9918: 	 Predicted label is:horse
# Test case 9919: 	 Predicted label is:deer
# Test case 9920: 	 Predicted label is:bird
# Test case 9921: 	 Predicted label is:plane
# Test case 9922: 	 Predicted label is:truck
# Test case 9923: 	 Predicted label is:cat
# Test case 9924: 	 Predicted label is:plane
# Test case 9925: 	 Predicted label is:bird
# Test case 9926: 	 Predicted label is:deer
# Test case 9927: 	 Predicted label is:ship
# Test case 9928: 	 Predicted label is:cat
# Test case 9929: 	 Predicted label is:ship
# Test case 9930: 	 Predicted label is:cat
# Test case 9931: 	 Predicted label is:ship
# Test case 9932: 	 Predicted label is:plane
# Test case 9933: 	 Predicted label is:dog
# Test case 9934: 	 Predicted label is:deer
# Test case 9935: 	 Predicted label is:frog
# Test case 9936: 	 Predicted label is:ship
# Test case 9937: 	 Predicted label is:horse
# Test case 9938: 	 Predicted label is:truck
# Test case 9939: 	 Predicted label is:dog
# Test case 9940: 	 Predicted label is:dog
# Test case 9941: 	 Predicted label is:cat
# Test case 9942: 	 Predicted label is:horse
# Test case 9943: 	 Predicted label is:truck
# Test case 9944: 	 Predicted label is:horse
# Test case 9945: 	 Predicted label is:bird
# Test case 9946: 	 Predicted label is:plane
# Test case 9947: 	 Predicted label is:deer
# Test case 9948: 	 Predicted label is:deer
# Test case 9949: 	 Predicted label is:bird
# Test case 9950: 	 Predicted label is:deer
# Test case 9951: 	 Predicted label is:plane
# Test case 9952: 	 Predicted label is:bird
# Test case 9953: 	 Predicted label is:bird
# Test case 9954: 	 Predicted label is:ship
# Test case 9955: 	 Predicted label is:truck
# Test case 9956: 	 Predicted label is:ship
# Test case 9957: 	 Predicted label is:ship
# Test case 9958: 	 Predicted label is:car
# Test case 9959: 	 Predicted label is:bird
# Test case 9960: 	 Predicted label is:plane
# Test case 9961: 	 Predicted label is:ship
# Test case 9962: 	 Predicted label is:bird
# Test case 9963: 	 Predicted label is:ship
# Test case 9964: 	 Predicted label is:plane
# Test case 9965: 	 Predicted label is:cat
# Test case 9966: 	 Predicted label is:cat
# Test case 9967: 	 Predicted label is:deer
# Test case 9968: 	 Predicted label is:bird
# Test case 9969: 	 Predicted label is:frog
# Test case 9970: 	 Predicted label is:cat
# Test case 9971: 	 Predicted label is:ship
# Test case 9972: 	 Predicted label is:bird
# Test case 9973: 	 Predicted label is:ship
# Test case 9974: 	 Predicted label is:deer
# Test case 9975: 	 Predicted label is:horse
# Test case 9976: 	 Predicted label is:deer
# Test case 9977: 	 Predicted label is:deer
# Test case 9978: 	 Predicted label is:deer
# Test case 9979: 	 Predicted label is:plane
# Test case 9980: 	 Predicted label is:plane
# Test case 9981: 	 Predicted label is:deer
# Test case 9982: 	 Predicted label is:deer
# Test case 9983: 	 Predicted label is:horse
# Test case 9984: 	 Predicted label is:horse
# Test case 9985: 	 Predicted label is:dog
# Test case 9986: 	 Predicted label is:plane
# Test case 9987: 	 Predicted label is:ship
# Test case 9988: 	 Predicted label is:ship
# Test case 9989: 	 Predicted label is:deer
# Test case 9990: 	 Predicted label is:cat
# Test case 9991: 	 Predicted label is:ship
# Test case 9992: 	 Predicted label is:dog
# Test case 9993: 	 Predicted label is:cat
# Test case 9994: 	 Predicted label is:frog
# Test case 9995: 	 Predicted label is:cat
# Test case 9996: 	 Predicted label is:deer
# Test case 9997: 	 Predicted label is:bird
# Test case 9998: 	 Predicted label is:plane
# Test case 9999: 	 Predicted label is:dog
# K-NN 1
# accuracy: 0.310100
